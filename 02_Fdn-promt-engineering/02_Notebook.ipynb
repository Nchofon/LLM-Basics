# %% [markdown]
# # Task 2
#
# ## Create a prompt-engineering notebook with at least five prompt iterations for one practical task. The task may be summarisation, extraction, formatting, data generation, or question answering.

# %%
import os
from google import genai
from dotenv import load_dotenv

# %%
load_dotenv()

api_key = os.getenv("GEMINI_API_KEY")
model = os.getenv("GEMINI_MODEL")

client = genai.Client(api_key=api_key)

interaction = client.interactions.create(
    model=model,
    input="Explain how AI works in a few words"
)

print(interaction.output_text)
# Out:
# ---------------------------------------------------------------------------
# CreateInteractionClientError              Traceback (most recent call last)
# File c:\Users\STUDENT\Documents\LLM Basics\LLM-Basics\.venv\Lib\site-packages\google\genai\_gaos\interactions.py:563, in Interactions.create(self, request, api_version, extra_headers, extra_query, extra_body, timeout, **body_kwargs)
#     562 try:
# --> 563     return _speakeasy_parse_response(http_res)
#     564 except Exception as parse_exc_:
#
# File c:\Users\STUDENT\Documents\LLM Basics\LLM-Basics\.venv\Lib\site-packages\google\genai\_gaos\interactions.py:492, in Interactions.create.<locals>._speakeasy_parse_response(http_res)
#     489     response_data = unmarshal_json_response(
#     490         errors.CreateInteractionClientErrorData, http_res, http_res_text
#     491     )
# --> 492     raise errors.CreateInteractionClientError(
#     493         response_data, http_res, http_res_text
#     494     )
#     495 except errors.ResponseValidationError as e:
#
# CreateInteractionClientError: Model 'gemini-3.5-flash-lite' not found. Did you mean 'gemini-3.1-flash-lite'? Please verify the model name against the supported list: https://ai.google.dev/gemini-api/docs/models
#
# The above exception was the direct cause of the following exception:
#
# NotFoundError                             Traceback (most recent call last)
# Cell In[4], line 8
#       4 model = os.getenv("GEMINI_MODEL")
#       5
#       6 client = genai.Client(api_key=api_key)
#       7
# ----> 8 interaction = client.interactions.create(
#       9     model=model,
#      10     input="Explain how AI works in a few words"
#      11 )
#
# File c:\Users\STUDENT\Documents\LLM Basics\LLM-Basics\.venv\Lib\site-packages\google\genai\_gaos\google_genai.py:271, in GeminiNextGenInteractions.create(self, request, api_version, extra_headers, extra_query, extra_body, timeout, **body)
#     269 stream = _optional_bool(body.get('stream'), default=False)
#     270 body = _normalize_create_body(body)
# --> 271 response = wrap_sdk_call(
#     272     super().create,
#     273     api_version=api_version,
#     274     **cast(Any, body),
#     275     extra_headers=extra_headers,
#     276     extra_query=extra_query,
#     277     extra_body=extra_body,
#     278     timeout=timeout,
#     279 )
#     280 if stream:
#     281     if is_stream(response):
#
# File c:\Users\STUDENT\Documents\LLM Basics\LLM-Basics\.venv\Lib\site-packages\google\genai\_gaos\lib\compat_errors.py:348, in wrap_sdk_call(fn, *args, **kwargs)
#     346 """Execute `fn(*args, **kwargs)`, translating known SDK exceptions."""
#     347 try:
# --> 348     return fn(*args, **kwargs)
#     349 except _WRAP_EXCEPTIONS as exc:
#     350     raise wrap_sdk_error(exc) from exc
#
# File c:\Users\STUDENT\Documents\LLM Basics\LLM-Basics\.venv\Lib\site-packages\google\genai\_gaos\interactions.py:565, in Interactions.create(self, request, api_version, extra_headers, extra_query, extra_body, timeout, **body_kwargs)
#     563     return _speakeasy_parse_response(http_res)
#     564 except Exception as parse_exc_:
# --> 565     response_helpers.raise_parse_error(
#     566         self.sdk_configuration.__dict__["_hooks"],
#     567         AfterParseErrorContext(_speakeasy_hook_ctx),
#     568         http_res,
#     569         parse_exc_,
#     570     )
#
# File c:\Users\STUDENT\Documents\LLM Basics\LLM-Basics\.venv\Lib\site-packages\google\genai\_gaos\utils\response_helpers.py:92, in raise_parse_error(hooks, hook_ctx, response, exc)
#      90 if parse_error is exc:
#      91     raise exc.with_traceback(exc.__traceback__)
# ---> 92 raise parse_error from exc
#
# NotFoundError: Error code: 404 - {'error': {'message': "Model 'gemini-3.5-flash-lite' not found. Did you mean 'gemini-3.1-flash-lite'? Please verify the model name against the supported list: https://ai.google.dev/gemini-api/docs/models", 'code': 'not_found'}}

# %% [markdown]
# # 1. A vague prompt and why it fails

# %%
interaction_1 = client.interactions.create(
    model=model,
    input="Prompt enginnering best practices"
)

print(interaction_1.output_text)
# Out:
# Prompt engineering is the practice of structuring and phrasing inputs (prompts) to get the most accurate, relevant, and useful responses from Large Language Models (LLMs).
#
# Here is a comprehensive guide to prompt engineering best practices, structured from foundational rules to advanced techniques.
#
# ---
#
# ## 1. The Core Principles (The Foundation)
#
# If you only remember three things, remember these:
#
# *   **Be Specific and Direct:** LLMs cannot read your mind. Instead of asking "Write a post about productivity," ask "Write a 300-word LinkedIn post about time-management techniques for remote software developers, focusing on the Pomodoro technique."
# *   **Provide Context:** Tell the AI *why* you are asking, *who* the audience is, and *what* the background is.
# *   **Give the AI a Persona (Role Prompting):** Activating a persona frames the AI's knowledge base.
#     *   *Example:* "Act as a Senior UX Researcher with 10 years of experience. Review this landing page copy..."
#
# ---
#
# ## 2. Structural Elements of a Great Prompt
#
# A perfect prompt is often structured like a mini-program. Use these elements (you don’t need all of them every time, but they help):
#
# 1.  **Role/Persona:** Who is the AI pretending to be? (e.g., "You are an expert copywriter.")
# 2.  **Instruction/Task:** What do you want it to do? (e.g., "Draft an email...")
# 3.  **Context/Data:** What information does it need? Use **delimiters** (like triple quotes `"""` or XML tags `<text></text>`) to separate instructions from the data.
# 4.  **Constraints:** What should it *not* do? (e.g., "Keep it under 150 words," "Do not use jargon.")
# 5.  **Output Format:** How should it look? (e.g., "Return a markdown table," "Output only valid JSON.")
#
# ### Example of a Structured Prompt:
# > **Role:** You are a professional editor.
# > **Task:** Summarize the text enclosed in the `<source_text>` tags below.
# > **Constraints:** The summary must be under 100 words, written for a 5th-grade reading level, and contain exactly 3 bullet points.
# > **Format:** Output in Markdown bullet points.
# >
# > `<source_text>`
# > [Insert your long text here]
# > `</source_text>`
#
# ---
#
# ## 3. Essential Techniques
#
# ### A. Few-Shot Prompting (Show, Don't Just Tell)
# Providing examples of the desired output is the single most effective way to improve accuracy.
# *   **Zero-Shot (No examples):** "Classify this review as Positive or Negative: 'The food was okay, but the service was slow.'"
# *   **Few-Shot (With examples):**
#     ```text
#     Review: "The product arrived early and works perfectly!"
#     Sentiment: Positive
#
#     Review: "It broke after two days. Do not buy."
#     Sentiment: Negative
#
#     Review: "The food was okay, but the service was slow."
#     Sentiment:
#     ```
#
# ### B. Chain-of-Thought (CoT) Prompting
# For complex reasoning, math, or logic, force the AI to explain its thinking step-by-step. This drastically reduces errors (hallucinations).
# *   *How to use:* Simply add **"Think step-by-step before answering"** to your prompt.
# *   *Why it works:* It forces the LLM to generate intermediate reasoning tokens, which guides it to the correct conclusion.
#
# ### C. Negative Constraints (What to Avoid)
# Explicitly state what the AI should *not* do.
# *   "Do not use passive voice."
# *   "Do not apologize or explain your reasoning; output only the code."
# *   "Avoid cliché phrases like 'In today's digital landscape' or 'It's important to remember...'"
#
# ---
#
# ## 4. Formatting and Output Control
#
# When building applications or analyzing data, you need predictable formats.
#
# *   **Request JSON or YAML:** If you are feeding the output into another program, ask for JSON.
#     *   *Tip:* Provide a schema. *"Output in JSON format with the keys: 'sentiment_score' (0-1), 'summary' (string), and 'keywords' (array of strings)."*
# *   **Use Markdown for Readability:** Ask the AI to use bolding, headers, tables, and bullet points to make long answers digestible.
#
# ---
#
# ## 5. Iterative Refinement (The Prompting Workflow)
#
# Rarely does a prompt work perfectly on the first try. Use this workflow:
#
# 1.  **Draft:** Write your first version based on the core principles.
# 2.  **Evaluate:** Run the prompt. Where did it fail? (Did it get too wordy? Did it miss a point?)
# 3.  **Refine:** Adjust the prompt. If it was too wordy, add a length constraint. If it missed a point, use bold text to emphasize that instruction.
# 4.  **Test:** Test it on multiple inputs to ensure consistency.
#
# ---
#
# ## 6. Advanced Tips for Programmers & Power Users
#
# *   **Temperature Settings:**
#     *   Set **Temperature to 0** (or very low) for factual tasks, coding, and data extraction (highly deterministic).
#     *   Set **Temperature to 0.7 - 1.0** for creative writing, brainstorming, and marketing copy (highly creative).
# *   **System Prompts:** If you are using an API (like OpenAI's or Anthropic's), use the `System` role for overall rules and behavior (e.g., "You are a helpful assistant who always responds in French") and the `User` role for the specific task at hand.
# *   **Preventing Hallucinations:** When asking about factual data, give the AI an out.
#     *   *Example:* "If you do not know the answer based on the provided text, write 'Information not found.' Do not make up facts."
#
# ---
#
# ## Quick Checklist before hitting "Send"
#
# - [ ] Did I give the AI a role?
# - [ ] Is the main instruction clear and action-oriented (e.g., "Analyze," "Write," "Summarize")?
# - [ ] Are inputs separated from instructions using delimiters (like `"""`)?
# - [ ] Have I specified the exact length and format I want?
# - [ ] (If complex) Did I provide an example of what a good output looks like?

# %% [markdown]
# ## Response:
#
# 1. The exact prompt: "Prompt enginnering best practices"
# 2. The model response: Refere to the cell above
# 3. What was wrong or incomplete: A lot of information was returned back to the user. It was not precise and the response had no structure.

# %% [markdown]
# # 2. A specific prompt with role, task, context, and output format.

# %%
interaction_2 = client.interactions.create(
    model=model,
    input="You a machine learning professor of an R1 university. In as few as 50 words, you want to explain to your students in simple terms what best practices they should adopt when writing prompts for LLMs. Your response should be in the following format: Title: Body: Example: Conclusion:"
)

print(interaction_2.output_text)
# Out:
# Title: Prompt Engineering 101
#
# Body: Treat LLMs like eager research assistants: provide clear context, define their role, and specify your desired output format.
#
# example: "Act as an editor. Proofread this abstract for clarity: [text]"
#
# Conclusion: Clear constraints yield optimal outputs.

# %% [markdown]
# ## Response:
#
# 1. The exact prompt: "You a machine learning professor of an R1 university. In as few as 50 words, you want to explain to your students in simple terms what best practices they should adopt when writing prompts for LLMs. Your response should be in the following format: Title: Body: Example: Conclusion:"
#
# 2. The model response: Refer to the cell above
#
# 3. What was wrong or incomplete: The structure was not very clear but more concise.
#
# 4. What changed in the next prompt: The prompt now had a precise example.
#
# 5. Whether the output improved: The response was improved.

# %% [markdown]
# # 3. Use of examples or constraints.

# %%
interaction_3 = client.interactions.create(
    model=model,
    input="""You a machine learning professor of an R1 university. In as few as 70 words, you want to explain to your students in simple terms what best practices they should adopt when writing prompts for LLMs. Your response should be in the following format: Title: Body: example Conclusion: Example:
    
    Title: Prompt best practices  
    
    Treat LLMs like eager research assistants: provide clear context, define their role, and specify your desired output format.
    
    An example of a good prompt is: "You as an expert speaking to a five year old, explain the concept of prompt engineering in less than 20 words. Use simple terms for a novice." """
)

print(interaction_3.output_text)
# Out:
# Title: Prompting Best Practices
#
# Body: Treat LLMs as smart, literal TAs. To get the best results, define their role, provide clear context, and specify constraints.
#
# Example: "Act as an ML professor. Explain overfitting to a novice in one sentence."
#
# Conclusion: Precise inputs yield precise outputs.

# %% [markdown]
# ## Response:
#
# 1. The exact prompt: Please refer to the cell above
#
# 2. The model response: Please refer to the cell above
#
# 3. What was wrong or incomplete: The structure was improved but not as intended. It stated the section of the response which could be ommited like Tittle, Body, ....
#
# 4. What changed in the next prompt: The structure of the desired output was defined clearer. We are using a table in this case. 3 rules were included in the prompt.
#
# 5. Whether the output improved: The response was improved.

# %% [markdown]
# # 4. A structured output request, such as JSON, table, or bullet list.

# %%
interaction_4a = client.interactions.create(
    model=model,
    input="""You are a machine learning professor.
Create a markdown table of 3 prompt engineering best practices.
Columns:
| Practice | Why it matters | Bad prompt | Good prompt |
Rules:
- Exactly 3 rows
- Return only the table
- No extra text"""
)
print(interaction_4a.output_text)
# Out:
# | Practice | Why it matters | Bad prompt | Good prompt |
# | :--- | :--- | :--- | :--- |
# | **Assign a Persona (Context Setting)** | Anchors the model in a relevant domain of its latent space, improving the tone, depth, and relevance of the generated response. | "Explain backpropagation." | "Act as a machine learning professor. Explain backpropagation to a college freshman using an analogy." |
# | **Few-Shot Prompting (In-Context Learning)** | Demonstrates expected output patterns, constraints, and formats, reducing variance in responses without weight updates. | "Classify this review as Positive or Negative: 'The training took forever and overfitted.'" | "Classify ML reviews.\n\nInput: 'Great loss convergence!' -> Output: Positive\nInput: 'The model gradient exploded.' -> Output: Negative\nInput: 'The training took forever and overfitted.' -> Output:" |
# | **Specify Output Structure & Constraints** | Ensures the output is formatted deterministically, allowing downstream APIs and code to easily parse the generated text. | "List some activation functions." | "List 3 activation functions. Return only a JSON array of objects with the keys 'name', 'range', and 'is_nonlinear' (boolean)." |

# %% [markdown]
# ## Response:
#
# 1. The exact prompt: Please refer to the cell above
#
# 2. The model response: Please refer to the cell above
#
# 3. What was wrong or incomplete: The structure followed the description very closely. However, some unwanted characters in the cell.
#
# 4. What changed in the next prompt: More rules were added like: "Do NOT use line breaks inside cells", "Do NOT use literal \\n in the output" A response example was also included.
#
# 5. Whether the output improved: The response was improved.

# %% [markdown]
# # 5. Handling an imperfect output from the LLM.

# %%
interaction_4a = client.interactions.create(
    model=model,
    input="""You are a machine learning professor.

Create a markdown table of exactly 3 prompt engineering best practices.

Columns:
| Practice | Why it matters | Bad prompt | Good prompt |

Rules:
- Return ONLY the table
- Exactly 3 data rows
- Each cell must be ONE line only
- Do NOT use line breaks inside cells
- Do NOT use literal \\n in the output
- Keep each cell under 20 words
- Put prompt examples in double quotes
- Complete every row fully — do not leave any cell empty
- If an example would be long, shorten it

Example row format:
| Few-shot prompting | Shows the model the expected pattern | "Classify this review" | "Classify as Positive/Negative. Example: 'Great model!' -> Positive" |
"""
)
print(interaction_4a.output_text)
# Out:
# | Practice | Why it matters | Bad prompt | Good prompt |
# | :--- | :--- | :--- | :--- |
# | Role Prompting | Sets the context and tone for expert-level responses | "Explain backpropagation." | "As an ML professor, explain backpropagation simply." |
# | Chain of Thought | Improves accuracy in complex reasoning and math | "What is 15% of 120?" | "What is 15% of 120? Think step-by-step." |
# | Use Delimiters | Clearly separates instructions from the input data | "Summarize the text about gradient descent." | "Summarize the text below. Text: ### Gradient descent... ###" |

# %% [markdown]
# ## Response:
#
# 1. The exact prompt: Please refer to the cell above
#
# 2. The model response: Please refer to the cell above
#
# 3. What was wrong or incomplete: The structure followed the description very closely. Also, no strange characters were included like \\n
#
# 4. //
#
# 5. Whether the output improved: The response was improved.
